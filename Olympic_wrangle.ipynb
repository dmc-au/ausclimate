# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(
    "./Data/Olympic/Kaggle2/athlete_events.csv",
    encoding="ISO-8859-1"
)

# %%
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 1         1724              Aristidis Akratopoulos   M   NaN     NaN     NaN
# 2         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 3         1725  Konstantinos "Kostas" Akratopoulos   M   NaN     NaN     NaN
# 4         4113                  Anastasios Andreou   M   NaN     NaN     NaN
# ...        ...                                 ...  ..   ...     ...     ...
# 271111  135528                       Marc Zwiebler   M  32.0   181.0    75.0
# 271112  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 271113  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 271114  135547       Viktoriya Viktorovna Zyabkina   F  23.0   174.0    62.0
# 271115  135568              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
# ...

# %%
country_sum = pd.DataFrame(
    df.groupby(by=['NOC'])['Medal Val'].sum()
).sort_values(by=['Medal Val'], ascending=False)[0:10]
country_sum
# Out:
#      Medal Val
# NOC
# USA       5637
# URS       2503
# GER       2165
# GBR       2068
# FRA       1777
# ITA       1637
# SWE       1536
# CAN       1352
# AUS       1320
# RUS       1165

# %%
plt.figure()
country_sum.plot.bar(
    figsize=(10,10),
)
plt.title(
    "Total Olympic Medal Count by Country (1896-2016)",
    size=16
)
plt.xlabel('Country')
# plt.ylabel('Medal count')
plt.legend(
    labels=['Medal count'],
    loc=1,
    prop={'size': 12}
)
plt.show()
