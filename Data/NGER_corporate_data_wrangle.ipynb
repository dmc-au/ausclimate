# %% [markdown]
# # NGER Corporate Data
#
# Wrangling the last ~20 years worth of csvs of energy consumption and emissions.

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
from matplotlib import pyplot as plt

# %%
remove_space_and_comma = lambda x: (x.strip().replace(',',''))

# %%
# Dataframe definition
df2021 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2020-21.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total scope 1 emissions (t CO2-e)": remove_space_and_comma,
        "Total scope 2 emissions (t CO2-e)": remove_space_and_comma,
        "Net energy consumed (GJ)": remove_space_and_comma,
    }
)
df2021
# Out:
#                                      Organisation name Identifying details  \
# 0                                   AGL ENERGY LIMITED      74 115 061 375
# 1                     ENERGYAUSTRALIA HOLDINGS LIMITED      57 101 876 135
# 2                         STANWELL CORPORATION LIMITED      37 078 848 674
# 3                                ORIGIN ENERGY LIMITED      30 000 051 696
# 4                                   C S ENERGY LIMITED      54 078 848 745
# ..                                                 ...                 ...
# 404  DIGITAL AUSTRALIA INVESTMENT MANAGEMENT PTY LI...      27 150 294 134
# 405                       MCDONALD'S AUSTRALIA LIMITED      43 008 496 928
# 406                GLOBAL SWITCH AUSTRALIA PTY LIMITED      65 094 338 333
# 407              MOORABOOL WIND FARM (HOLDING) PTY LTD      45 614 439 691
# 408        LYONDELLBASELL AUSTRALIA (HOLDINGS) PTY LTD      74 066 270 237
#
# ...

# %%
df2020 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2019-20.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total scope 1 emissions (t CO2-e)": remove_space_and_comma,
        "Total scope 2 emissions (t CO2-e)": remove_space_and_comma,
        "Net energy consumed (GJ)": remove_space_and_comma,
    }
)
df2020
# Out:
#                                      Organisation name Identifying details  \
# 0                                   AGL ENERGY LIMITED      74 115 061 375
# 1                     ENERGYAUSTRALIA HOLDINGS LIMITED      57 101 876 135
# 2                         STANWELL CORPORATION LIMITED      37 078 848 674
# 3                                ORIGIN ENERGY LIMITED      30 000 051 696
# 4                                   C S ENERGY LIMITED      54 078 848 745
# ..                                                 ...                 ...
# 410                       MCDONALD'S AUSTRALIA LIMITED      43 008 496 928
# 411                 AIRTRUNK AUSTRALIA HOLDING PTY LTD      50 616 379 232
# 412  DIGITAL AUSTRALIA INVESTMENT MANAGEMENT PTY LI...      27 150 294 134
# 413                GLOBAL SWITCH AUSTRALIA PTY LIMITED      65 094 338 333
# 414        LYONDELLBASELL AUSTRALIA (HOLDINGS) PTY LTD      74 066 270 237
#
# ...

# %%
df2019 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2018-19.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Net Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2019
# Out:
#                   Organisation Name Identifying Details  \
# 0     A B C TISSUE PRODUCTS PTY LTD      33 003 085 112
# 1    A.A. SCOTT PROPRIETARY LIMITED      14 007 601 667
# 2        A.C.N. 085 239 998 PTY LTD      39 085 239 998
# 3        A.C.N. 166 119 133 PTY LTD      31 166 119 133
# 4          A.J. BUSH & SONS PTY LTD      77 000 134 010
# ..                              ...                 ...
# 413         WOLLONGONG COAL LIMITED      28 111 244 896
# 414         WOODSIDE PETROLEUM LTD.      55 004 898 962
# 415        WOOLWORTHS GROUP LIMITED      88 000 014 675
# 416       YANCOAL AUSTRALIA LIMITED      82 111 859 119
# 417          YARA AUSTRALIA PTY LTD      77 076 301 221
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# 0                               25513                             59864
# 1                              173907                              6979
# 2                                1593                            172624
# ...

# %%
df2018 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2017-18.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Net Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2018
# Out:
#                         Organisation Name Identifying Details  \
# 0           A B C TISSUE PRODUCTS PTY LTD      33 003 085 112
# 1          A.A. SCOTT PROPRIETARY LIMITED      14 007 601 667
# 2              A.C.N. 085 239 998 PTY LTD      39 085 239 998
# 3              A.C.N. 166 119 133 PTY LTD      31 166 119 133
# 4                A.J. BUSH & SONS PTY LTD      77 000 134 010
# ..                                    ...                 ...
# 408               WOODSIDE PETROLEUM LTD.      55 004 898 962
# 409              WOOLWORTHS GROUP LIMITED      88 000 014 675
# 410  WRIGLEY UNO 2 AUSTRALIA PTY. LIMITED      68 133 509 930
# 411             YANCOAL AUSTRALIA LIMITED      82 111 859 119
# 412                YARA AUSTRALIA PTY LTD      77 076 301 221
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# 0                               23396                             58379
# 1                              186888                              7660
# ...

# %%
df2017 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2016-17.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Net Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2017
# Out:
#              Controlling Corporation           ABN  \
# 0       A B C TISSUE PRODUCTS PTY LTD  33003085112
# 1      A.A. SCOTT PROPRIETARY LIMITED  14007601667
# 2          A.C.N. 004 410 833 LIMITED  63004410833
# 3          A.C.N. 085 239 998 PTY LTD  39085239998
# 4            A.J. BUSH & SONS PTY LTD  77000134010
# ..                                ...          ...
# 400           WOLLONGONG COAL LIMITED  28111244896
# 401           WOODSIDE PETROLEUM LTD.  55004898962
# 402          WOOLWORTHS GROUP LIMITED  88000014675
# 403         YANCOAL AUSTRALIA LIMITED  82111859119
# 404  YARA PILBARA FERTILISERS PTY LTD  74095441151
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# 0                               22997                             57998
# 1                              227196                              8755
# 2                             2744046                            990321
# ...

# %%
df2016 = pd.read_csv(
    "./NGER/Corporate/Greenhouse and energy information by registered corporation 2015-16.csv",
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Net Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2016
# Out:
#                                Controlling corporation          ABN  \
# 0                        A B C TISSUE PRODUCTS PTY LTD  33003085112
# 1                       A.A. SCOTT PROPRIETARY LIMITED  14007601667
# 2                           A.C.N. 085 239 998 PTY LTD  39085239998
# 3                             A.J. BUSH & SONS PTY LTD  77000134010
# 4                                         AAPC LIMITED  87009175820
# ..                                                 ...          ...
# 394                             WOODSIDE PETROLEUM LTD  55004898962
# 395                                     WOOLWORTHS LTD  88000014675
# 396                          YANCOAL AUSTRALIA LIMITED  82111859119
# 397                   YARA PILBARA FERTILISERS PTY LTD  74095441151
# 398  YFG SHOPPING CENTRES PTY LTD AS TRUSTEE FOR TH...  56853441699
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# 0                               25224                             57381
# ...

# %%
df2015 = pd.read_csv(
    "./NGER/Corporate/2014-15 Greenhouse and energy information by registered corporation.csv", 
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Net Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2015
# Out:
#                               Controlling Corporation            ABN  \
# 0                        A B C TISSUE PRODUCTS PTY LTD  3.300309e+10
# 1                                   A.A. Scott Pty Ltd  1.400760e+10
# 2                           A.C.N. 085 239 998 PTY LTD  3.908524e+10
# 3                             A.J. Bush & Sons Pty Ltd  7.700013e+10
# 4                                         AAPC LIMITED  8.700918e+10
# ..                                                 ...           ...
# 401                                     Woolworths Ltd  8.800001e+10
# 402                              Yancoal Australia Ltd  8.211186e+10
# 403                   Yara Pilbara Fertilisers Pty Ltd  7.409544e+10
# 404  YFG Shopping Centres Ltd Pty as Trustee for th...  5.685344e+10
# 405                                 YOLARNO PTY LTD     9.500226e+10
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# ...

# %%
df2014 = pd.read_csv(
    "./NGER/Corporate/2013-14 Greenhouse and energy information by registered corporation.csv", 
    encoding="ISO-8859-1",
    converters={
        "Identifying details": remove_space_and_comma,
        "Total Scope 1 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Scope 2 Emissions (t CO2-e)": remove_space_and_comma,
        "Total Net Energy consumed  (GJ)": remove_space_and_comma,
    }
)
df2014
# Out:
#              Controlling Corporation           ABN  \
# 0       A B C TISSUE PRODUCTS PTY LTD  33003085112
# 1                  A.A. Scott Pty Ltd  14007601667
# 2          A.C.N. 085 239 998 PTY LTD  39085239998
# 3            A.J. Bush & Sons Pty Ltd  77000134010
# 4                        AAPC LIMITED  87009175820
# ..                                ...          ...
# 408           Woodside Petroleum Ltd.  55004898962
# 409                    Woolworths Ltd  88000014675
# 410             Yancoal Australia Ltd  82111859119
# 411  Yara Pilbara Fertilisers Pty Ltd  74095441151
# 412     YFG Shopping Centres  Pty Ltd  56853441699
#
#     Total Scope 1 Emissions (t CO2-e) Total Scope 2 Emissions (t CO2-e)  \
# 0                               25660                             61440
# 1                              158272                              6841
# 2                                6832                            193789
# ...

# %%
df2013 = pd.read_csv(
    "./NGER/Corporate/2012-13 Greenhouse and energy information by registered corporation.csv", 
    encoding="ISO-8859-1",
    converters={
        # Identifying details: remove_space_and_comma,
        "Corporate Total Scope 1 Emission (t CO2-e)": remove_space_and_comma,
        "Corporate Total Scope 2 Emission (t CO2-e)": remove_space_and_comma,
        "Corporate Total Energy Consumed (GJ)": remove_space_and_comma,
    }
)
df2013
# Out:
#          Controlling Corporation Name  \
# 0             A J Bush & Sons Pty Ltd
# 1                  A.A. Scott Pty Ltd
# 2                        AAPC Limited
# 3     ABC Tissue Products Pty Limited
# 4             ACN 085 239 998 PTY LTD
# ..                                ...
# 405                    Woolworths Ltd
# 406          XSTRATA HOLDINGS PTY LTD
# 407         Yancoal Australia Limited
# 408  Yara Pilbara Fertilisers Pty Ltd
# 409     YFG Shopping Centres  Pty Ltd
#
#     Corporate Total Scope 1 Emission (t CO2-e)  \
# 0                                       102372
# 1                                       160531
# 2                                        19700
# 3                                        17361
# 4                                         6262
# ..                                         ...
# 405                                     444665
# 406                                    3631066
# 407                                     956908
# ...

# %%
dfs = [
    df2021,df2020,df2019,
    df2018,df2017,df2016,
    df2015,df2014 #df2013 is special
]

# %%
# Dataframe of corporate emissions 2013-2021
years = [
    '2021','2020','2019',
    '2018','2017','2016',
    '2015','2014'#,'2013'
]
BASELINE = 1_000_000
s1 = [pd.to_numeric(pd.DataFrame(df).iloc[:,2], errors='coerce').sum()/BASELINE for df in dfs]
s2 = [pd.to_numeric(pd.DataFrame(df).iloc[:,3], errors='coerce').sum()/BASELINE for df in dfs]
total_energy = [pd.to_numeric(pd.DataFrame(df).iloc[:,3], errors='coerce').sum() for df in dfs]

# s1.append(pd.to_numeric(pd.DataFrame(df2013).iloc[:,1], errors='coerce').sum())
# s2.append(pd.to_numeric(pd.DataFrame(df2013).iloc[:,2], errors='coerce').sum())
# total_energy.append(pd.to_numeric(pd.DataFrame(df2013).iloc[:,3], errors='coerce').sum())

df_total = pd.DataFrame(data={
    'years': years,
    'scope 1 sum': s1,
    'scope 2 sum': s2,
    'total energy consumed': total_energy
}).loc[::-1]
df_total.to_csv('./NGER/Corporate/total_corporate.csv', index=False)
df_total
# Out:
#   years  scope 1 sum  scope 2 sum  total energy consumed
# 7  2014   305.811638    88.168807             88168807.0
# 6  2015   321.884485    86.918967             86918967.0
# 5  2016   329.078460    86.619458             86619458.0
# 4  2017   336.057561    82.628334             82628334.0
# 3  2018   336.663347    83.156580             83156580.0
# 2  2019   338.612986    84.743584             84743584.0
# 1  2020   327.988786    82.726587             82726587.0
# 0  2021   314.876645    81.012938             81012938.0

# %%
# Total scope 1 & 2 CO2
total_scope_sum = df_total['scope 1 sum'] + df_total['scope 2 sum']
total_scope_sum
plt.clf()
plt.bar(df_total['years'], total_scope_sum)
# Out:
# <BarContainer object of 8 artists>

# %%
# Total energy consumed
plt.clf()
plt.bar(df_total['years'], df_total['total energy consumed'])
# Out:
# <BarContainer object of 8 artists>

# %% [markdown]
# The reporting for total energy must have changed from 2012-13 to 2013-14

# %%
# Stackplot of scope 1 and 2 CO2
plt.clf()
plt.stackplot(df_total['years'], df_total['scope 2 sum'], df_total['scope 1 sum'])
plt.title('Corporate Total Emissions (t CO2-e)')
# Out:
# Text(0.5, 1.0, 'Corporate Total Emissions (t CO2-e)')

# %%
df_total
# Out:
#   years  scope 1 sum  scope 2 sum  total energy consumed
# 7  2014   305.811638    88.168807             88168807.0
# 6  2015   321.884485    86.918967             86918967.0
# 5  2016   329.078460    86.619458             86619458.0
# 4  2017   336.057561    82.628334             82628334.0
# 3  2018   336.663347    83.156580             83156580.0
# 2  2019   338.612986    84.743584             84743584.0
# 1  2020   327.988786    82.726587             82726587.0
# 0  2021   314.876645    81.012938             81012938.0

# %%
314.876645 + 81.012938
# Out:
# 395.889583
